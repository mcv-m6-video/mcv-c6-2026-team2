# %%
import os
os.environ["HF_TOKEN"] = ""

# %%
from huggingface_hub import snapshot_download
snapshot_download(repo_id="SoccerNet/SN-BAS-2025",
                  repo_type="dataset", revision="main",
                  local_dir="/ghome/group02/datasets/SoccerNet/SN-BAS-2025")
# Out:
# Fetching 9 files: 100%|██████████| 9/9 [02:48<00:00, 18.68s/it]
# '/export/home/group02/datasets/SoccerNet/SN-BAS-2025'
